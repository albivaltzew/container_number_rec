# %% [markdown]
# <a href="https://colab.research.google.com/github/albivaltzew/container_number_rec/blob/main/OpenMMOCR_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MMOCR Tutorial
#
# Welcome to MMOCR! This is the official colab tutorial for using MMOCR. In this tutorial, you will learn how to
#
# - Install MMOCR from source
# - Perform inference with
#   - a pretrained text recognizer
#   - a pretrained text detector
#   - pretrained recognizer and detector
#   - pretrained Key Information Extraction (KIE) model
# - Evaluate a text detection model on an acadmic dataset
# - Train a text recognizer with a toy dataset
#
# Let's start!

# %% [markdown]
# ## Install MMOCR from source
#
# Installing MMOCR is straightforward. We recommend users to install MMOCR from source as any local code changes on MMOCR can take effect immediately, which is needed for research & developement purpose. Refer to [documentation](https://mmocr.readthedocs.io/en/dev-1.x/get_started/install.html) for more information.

# %% [markdown]
# ### Install Dependencies using MIM

# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install 'mmcv>=2.0.0rc1'
# !mim install 'mmdet>=3.0.0rc0'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openmim
#   Downloading openmim-0.3.7-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.3)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (1.5.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (23.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.27.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.3.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.8.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.4.3)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Installing collected packages: ordered-set, colorama, model-index, openmim
# Successfully installed colorama-0.4.6 model-index-0.1.11 openmim-0.3.7 ordered-set-4.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.7.4-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.3/374.3 kB 9.4 MB/s eta 0:00:00
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmengine) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmengine) (6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine) (13.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine) (2.3.0)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.40.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmengine) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (2.14.0)
# Collecting importlib-metadata>=6.6.0 (from yapf->mmengine)
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting platformdirs>=3.5.1 (from yapf->mmengine)
#   Downloading platformdirs-3.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Installing collected packages: addict, platformdirs, importlib-metadata, yapf, mmengine
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.3.0
#     Uninstalling platformdirs-3.3.0:
#       Successfully uninstalled platformdirs-3.3.0
# Successfully installed addict-2.4.0 importlib-metadata-6.7.0 mmengine-0.7.4 platformdirs-3.8.0 yapf-0.40.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv>=2.0.0rc1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.0.0-cp310-cp310-manylinux1_x86_64.whl (74.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (0.7.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (23.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (6.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (0.40.1)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (4.7.0.72)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (3.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (13.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.3.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (6.7.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (3.8.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv>=2.0.0rc1) (3.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmdet>=3.0.0rc0
#   Downloading mmdet-3.0.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (1.22.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (2.0.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (1.10.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (1.16.0)
# Collecting terminaltables (from mmdet>=3.0.0rc0)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: mmcv<2.1.0,>=2.0.0rc4 in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (2.0.0)
# Requirement already satisfied: mmengine<1.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc0) (0.7.4)
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (2.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (23.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (6.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (0.40.1)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (4.7.0.72)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0rc0) (13.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0rc0) (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc0) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0rc0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0rc0) (2.14.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (6.7.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (3.8.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv<2.1.0,>=2.0.0rc4->mmdet>=3.0.0rc0) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine<1.0.0,>=0.7.1->mmdet>=3.0.0rc0) (0.1.2)
# Installing collected packages: terminaltables, mmdet
# Successfully installed mmdet-3.0.0 terminaltables-3.1.10

# %% [markdown]
# ### Install MMOCR

# %%
# !git clone https://github.com/open-mmlab/mmocr.git
# %cd mmocr
# !pip install -v -e .
# "-v" increases pip's verbosity.
# "-e" means installing the project in editable mode,
# That is, any local modifications on the code will take effect immediately.
# Out:
# Cloning into 'mmocr'...
# remote: Enumerating objects: 16277, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 16277 (delta 56), reused 136 (delta 41), pack-reused 16089
# Receiving objects: 100% (16277/16277), 16.23 MiB | 23.57 MiB/s, done.
# Resolving deltas: 100% (10663/10663), done.
# /content/mmocr
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/mmocr
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info
#   writing /tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'mmocr/.mim/model-index.yml'
#   warning: no files found matching 'mmocr/.mim/dicts/*.txt'
#   warning: no files found matching '*.py' under directory 'mmocr/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmocr/.mim/configs'
#   warning: no files found matching '*.sh' under directory 'mmocr/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmocr/.mim/tools'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-wp20gfyj/mmocr.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from mmocr==1.0.0) (0.4.0)
# Collecting lmdb (from mmocr==1.0.0)
#   Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmocr==1.0.0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmocr==1.0.0) (1.22.4)
# Requirement already satisfied: opencv-python!=4.5.5.*,>=4.2.0.32 in /usr/local/lib/python3.10/dist-packages (from mmocr==1.0.0) (4.7.0.72)
# Collecting pyclipper (from mmocr==1.0.0)
#   Downloading pyclipper-1.3.0.post4-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 48.9 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from mmocr==1.0.0) (2.0.6)
# Collecting rapidfuzz>=2.0.0 (from mmocr==1.0.0)
#   Downloading rapidfuzz-3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 51.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from mmocr==1.0.0) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->mmocr==1.0.0) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->mmocr==1.0.0) (1.10.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug->mmocr==1.0.0) (8.4.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->mmocr==1.0.0) (2.25.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug->mmocr==1.0.0) (2.0.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->mmocr==1.0.0) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->mmocr==1.0.0) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->mmocr==1.0.0) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->mmocr==1.0.0) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmocr==1.0.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmocr==1.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmocr==1.0.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmocr==1.0.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmocr==1.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmocr==1.0.0) (2.8.2)
# Installing collected packages: pyclipper, lmdb, rapidfuzz, mmocr
#   Running setup.py develop for mmocr
#     Running command python setup.py develop
#     running develop
#     /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` and ``easy_install``.
#             Instead, use pypa/build, pypa/installer, pypa/build or
#             other standards-based tools.
#
#             See https://github.com/pypa/setuptools/issues/917 for details.
#             ********************************************************************************
#
#     !!
#       easy_install.initialize_options(self)
#     /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` directly.
#             Instead, use pypa/build, pypa/installer, pypa/build or
#             other standards-based tools.
#
#             See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#             ********************************************************************************
#
#     !!
#       self.initialize_options()
#     running egg_info
#     creating mmocr.egg-info
#     writing mmocr.egg-info/PKG-INFO
#     writing dependency_links to mmocr.egg-info/dependency_links.txt
#     writing requirements to mmocr.egg-info/requires.txt
#     writing top-level names to mmocr.egg-info/top_level.txt
#     writing manifest file 'mmocr.egg-info/SOURCES.txt'
#     reading manifest file 'mmocr.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     adding license file 'LICENSE'
#     writing manifest file 'mmocr.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /usr/local/lib/python3.10/dist-packages/mmocr.egg-link (link to .)
#     Adding mmocr 1.0.0 to easy-install.pth file
#
#     Installed /content/mmocr
# Successfully installed lmdb-1.4.1 mmocr-1.0.0 pyclipper-1.3.0.post4 rapidfuzz-3.1.1

# %% [markdown]
# ## Inference
#
# MMOCR has made inference easy by providing a variety of `Inferencer`s. In this section, we will focus on the usage of `MMOCRInferencer`. However, if you want to learn more about other `Inferencer`s, you can refer to the [documentation](https://mmocr.readthedocs.io/en/dev-1.x/user_guides/inference.html) which provides detailed descriptions.

# %% [markdown]
# ### Perform Inference with a Pretrained Text Recognizer
#
# We now demonstrate how to inference on a demo text recognition image with a pretrained text recognizer. SVTR text recognizer is used for this demo, whose checkpoint can be found in the [official documentation](https://mmocr.readthedocs.io/en/dev-1.x/textrecog_models.html#svtr). But you don't need to download it manually -- Our Inferencer script handles these cumbersome setup steps for you!
#
# Run the following command and you will get the inference result from return value as well as files, which will be  visualized in the end.

# %%
from mmocr.apis import MMOCRInferencer
infer = MMOCRInferencer(rec='svtr-small')
result = infer('/content/Unknown-7.png', save_vis=True, return_vis=True)
print(result['predictions'])
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/textrecog/svtr/svtr-small_20e_st_mj/svtr-small_20e_st_mj-35d800d6.pth
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [{'rec_texts': ['22g1'], 'rec_scores': [0.9998399466276169]}]

# %%
# Visualize the return value
import matplotlib.pyplot as plt
plt.imshow(result['visualization'][0])
plt.show()

# %%
# Visualize the saved image
import mmcv
predicted_img = mmcv.imread('results/vis/demo_text_recog.jpg')
plt.imshow(mmcv.bgr2rgb(predicted_img))
plt.show()

# %% [markdown]
# ### Perform Inference with a Pretrained Text Detector
#
# Next, we perform inference with a pretrained DBNet++ text detector and visualize the bounding box results for the demo text detection image.

# %%
from mmocr.apis import MMOCRInferencer
infer = MMOCRInferencer(det='dbnetpp')
result = infer('/content/Unknown-7.png', return_vis=True)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/textdet/dbnetpp/dbnetpp_resnet50-oclip_fpnc_1200e_icdar2015/dbnetpp_resnet50-oclip_fpnc_1200e_icdar2015_20221101_124139-4ecb39ac.pth
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
infer = MMOCRInferencer(rec='svtr-small')
result = infer(plate, save_vis=True, return_vis=True)
print(result['predictions'])
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/textrecog/svtr/svtr-small_20e_st_mj/svtr-small_20e_st_mj-35d800d6.pth
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e9e955bf55e6> in <cell line: 2>()
#       1 infer = MMOCRInferencer(rec='svtr-small')
# ----> 2 result = infer(plate, save_vis=True, return_vis=True)
#       3 print(result['predictions'])
#
# NameError: name 'plate' is not defined

# %%
# Visualize the results
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 16))
plt.imshow(result['visualization'][0])
plt.show()

# %% [markdown]
# ### Perform end-to-end OCR with pretrained recognizer and detector
#
# We can  any text detector and recognizer into a pipeline that forms a standard OCR pipeline. Now we build our own OCR pipeline with DBNet++ and SVTR and apply it to `demo/demo_text_ocr.jpg`.

# %%
from mmocr.apis import MMOCRInferencer
infer = MMOCRInferencer(det='dbnetpp', rec='svtr-small')
result = infer('/content/1-124805001-OCR-LF-C01.jpg', return_vis=True)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/textdet/dbnetpp/dbnetpp_resnet50-oclip_fpnc_1200e_icdar2015/dbnetpp_resnet50-oclip_fpnc_1200e_icdar2015_20221101_124139-4ecb39ac.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/textrecog/svtr/svtr-small_20e_st_mj/svtr-small_20e_st_mj-35d800d6.pth
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Visualize the results
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 16))
plt.imshow(result['visualization'][0])
plt.show()

# %%
result
# Out:
# {'predictions': [{'det_polygons': [[1410.9798677884617,
#      548.1144118309021,
#      1437.6156850961538,
#      544.017584323883,
#      1440.5427970467033,
#      563.0385231971741,
#      1413.906979739011,
#      567.1353507041931],
#     [1410.4615384615386,
#      536.8359375,
#      1410.4615384615386,
#      498.8671875,
#      1452.6593406593406,
#      498.8671875,
#      1452.6593406593406,
#      536.8359375],
#     [1218.4464714972528,
#      420.1080894470215,
#      1224.1456473214287,
#      347.66430616378784,
#      1384.5245964972528,
#      360.2753019332886,
#      1378.825420673077,
#      432.7190852165222],
#     [1234.5526699862637,
#      325.4335677623749,
#      1239.110362293956,
#      259.81739580631256,
#      1458.6231541895604,
#      275.05762696266174,
#      1454.0654618818683,
#      340.67378282546997],
#     [1002.869634271978,
#      317.1396839618683,
#      1004.0391912774726,
#      250.4928356409073,
#      1173.6481370192307,
#      253.46768975257874,
#      1172.4785800137363,
#      320.11452198028564]],
#    'det_scores': [0.4941387176513672,
#     0.886363685131073,
#     0.9584909677505493,
#     0.952093243598938,
#     0.9524853825569153]}],
#  'visualization': [array([[[223, 253, 255],
#           [224, 254, 255],
#           [225, 255, 255],
#           ...,
#           [ 33,  49,  49],
#           [ 33,  49,  49],
#           [ 33,  49,  49]],
#
#          [[226, 254, 255],
#           [227, 255, 255],
#           [230, 255, 255],
#           ...,
#           [ 34,  50,  50],
#           [ 34,  50,  50],
#           [ 34,  50,  50]],
#
#          [[230, 255, 255],
#           [231, 255, 255],
#           [233, 255, 255],
#           ...,
#           [ 34,  50,  49],
#           [ 34,  50,  49],
#           [ 34,  50,  49]],
#
#          ...,
#
#          [[ 54,  20,  21],
#           [ 55,  21,  22],
#           [ 56,  22,  23],
#           ...,
#           [240, 249, 246],
#           [242, 251, 248],
#           [242, 251, 248]],
#
#          [[ 55,  21,  22],
#           [ 55,  21,  22],
#           [ 55,  21,  22],
#           ...,
#           [238, 247, 244],
#           [241, 250, 247],
#           [242, 251, 248]],
#
#          [[ 54,  20,  21],
#           [ 54,  20,  21],
#           [ 53,  19,  20],
#           ...,
#           [237, 246, 243],
#           [239, 248, 245],
#           [240, 249, 246]]], dtype=uint8)]}

# %% [markdown]
# ### Combine OCR with Downstream Tasks
#
# MMOCR also supports downstream tasks of OCR, such as key information extraction (KIE). We can even add a KIE model, SDMG-R, to the pipeline applied to `demo/demo_kie.jpeg` and visualize its prediction.

# %%
from mmocr.apis import MMOCRInferencer
infer = MMOCRInferencer(det='dbnetpp', rec='svtr-small', kie='SDMGR')
result = infer('demo/demo_kie.jpeg', save_vis=True)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/textdet/dbnetpp/dbnetpp_resnet50-oclip_fpnc_1200e_icdar2015/dbnetpp_resnet50-oclip_fpnc_1200e_icdar2015_20221101_124139-4ecb39ac.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/textrecog/svtr/svtr-small_20e_st_mj/svtr-small_20e_st_mj-35d800d6.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmocr/kie/sdmgr/sdmgr_unet16_60e_wildreceipt/sdmgr_unet16_60e_wildreceipt_20220825_151648-22419f37.pth
# Downloading: "https://download.openmmlab.com/mmocr/kie/sdmgr/sdmgr_unet16_60e_wildreceipt/sdmgr_unet16_60e_wildreceipt_20220825_151648-22419f37.pth" to /root/.cache/torch/hub/checkpoints/sdmgr_unet16_60e_wildreceipt_20220825_151648-22419f37.pth
# Output()
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: data_preprocessor.mean, data_preprocessor.std
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Visualize the results
import mmcv
import matplotlib.pyplot as plt
predicted_img = mmcv.imread('results/vis/demo_kie.jpg')
plt.figure(figsize=(18, 32))
plt.imshow(mmcv.bgr2rgb(predicted_img))
plt.show()

# %% [markdown]
# ## Training SAR on a Toy Dataset
#
# We now demonstrate how to train a recognizer on a provided dataset in a Python interpreter. Another common practice is to train a model from CLI (command line interface), as illustrated [here](https://mmocr.readthedocs.io/en/dev-1.x/get_started/quick_run.html#training).
#
# Since training a full academic dataset is time consuming (usually takes about several hours or even days), we will train on the toy dataset for the SAR text recognition model and visualize the predictions. Text detection and other downstream tasks such as KIE follow similar procedures.
#
# Training a model usually consists of the following steps:
# 1. Convert the dataset into [formats supported by MMOCR](https://mmocr.readthedocs.io/en/dev-1.x/basic_concepts/datasets.html). It should never be a concern if the dataset is obtained from Dataset Preparer. Otherwise, you will need to manually download and prepare the dataset following the [guide](https://mmocr.readthedocs.io/en/dev-1.x/user_guides/data_prepare/recog.html), or even have to write a custom conversion script if your dataset is not on the list.
# 2. Modify the config for training.
# 3. Train the model.
#
# In this example, we will use an off-the-shelf toy dataset to train SAR, and the first step will be skipped. The full demonstration of the first step can be found at the next section: Evaluating SAR on academic testsets.

# %% [markdown]
# ### Visualize the Toy Dataset
#
# We first get a sense of what the toy dataset looks like by visualizing one of the images and labels. The toy dataset consisits of ten images as well as annotation files in both json and lmdb format, and we only use json annotations in this tutorial.

# %%
import mmcv
import matplotlib.pyplot as plt

img = mmcv.imread('tests/data/rec_toy_dataset/imgs/1058891.jpg')
plt.imshow(mmcv.bgr2rgb(img))
plt.show()

# %%
# Inspect the labels of the annootation file
# !cat tests/data/rec_toy_dataset/labels.json

# %% [markdown]
# ### Load Config
#
# First we will load the toy config for SAR.

# %%
from mmengine import Config
# Load the config
cfg = Config.fromfile('configs/textrecog/sar/sar_resnet31_parallel-decoder_5e_toy.py')

# %% [markdown]
# In order to train SAR to its best state on toy dataset, we need to modify some hyperparameters in the config to accomodate some of the settings of colab.
# For more explanation about the config and its fields, please refer to [documentation](https://mmocr.readthedocs.io/en/dev-1.x/user_guides/config.html).

# %%
# Specify the work dir
cfg.work_dir = 'work_dirs/sar_resnet31_parallel-decoder_5e_toy/'
# Configure the batch size, learning rate, and maximum epochs
cfg.optim_wrapper.optimizer.lr = 1e-3
cfg.train_dataloader.batch_size = 5
cfg.train_cfg.max_epochs = 100
# Save checkpoint every 10 epochs
cfg.default_hooks.checkpoint.interval = 10

# We don't need any learning rate scheduler for a toy dataset
# thus clear parameter scheduler here
cfg.param_scheduler = None

# Set seed thus the results are more reproducible
cfg.randomness = dict(seed=0)

# We can initialize the logger for training and have a look
# at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# toy_data_root = 'tests/data/rec_toy_dataset/'
# toy_rec_train = dict(
#     type='OCRDataset',
#     data_root='tests/data/rec_toy_dataset/',
#     data_prefix=dict(img_path='imgs/'),
#     ann_file='labels.json',
#     pipeline=None,
#     test_mode=False)
# toy_rec_test = dict(
#     type='OCRDataset',
#     data_root='tests/data/rec_toy_dataset/',
#     data_prefix=dict(img_path='imgs/'),
#     ann_file='labels.json',
#     pipeline=None,
#     test_mode=True)
# default_scope = 'mmocr'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# randomness = dict(seed=0)
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=10),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffer=dict(type='SyncBuffersHook'),
#     visualization=dict(
#         type='VisualizationHook',
#         interval=1,
#         enable=False,
#         show=False,
#         draw_gt=False,
#         draw_pred=False))
# log_level = 'INFO'
# log_processor = dict(type='LogProcessor', window_size=10, by_epoch=True)
# load_from = None
# resume = False
# val_evaluator = dict(
#     type='MultiDatasetsEvaluator',
#     metrics=[
#         dict(
#             type='WordMetric',
#             mode=['exact', 'ignore_case', 'ignore_case_symbol']),
#         dict(type='CharMetric')
#     ],
#     dataset_prefixes=['Toy'])
# test_evaluator = dict(
#     type='MultiDatasetsEvaluator',
#     metrics=[
#         dict(
#             type='WordMetric',
#             mode=['exact', 'ignore_case', 'ignore_case_symbol']),
#         dict(type='CharMetric')
#     ],
#     dataset_prefixes=['Toy'])
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='TextRecogLocalVisualizer',
#     name='visualizer',
#     vis_backends=[dict(type='LocalVisBackend')])
# tta_model = dict(type='EncoderDecoderRecognizerTTAModel')
# optim_wrapper = dict(
#     type='OptimWrapper', optimizer=dict(type='Adam', lr=0.001))
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=100, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = None
# dictionary = dict(
#     type='Dictionary',
#     dict_file=
#     '/content/mmocr/configs/textrecog/sar/../../../dicts/english_digits_symbols.txt',
#     with_start=True,
#     with_end=True,
#     same_start_end=True,
#     with_padding=True,
#     with_unknown=True)
# model = dict(
#     type='SARNet',
#     data_preprocessor=dict(
#         type='TextRecogDataPreprocessor',
#         mean=[127, 127, 127],
#         std=[127, 127, 127]),
#     backbone=dict(type='ResNet31OCR'),
#     encoder=dict(
#         type='SAREncoder', enc_bi_rnn=False, enc_do_rnn=0.1, enc_gru=False),
#     decoder=dict(
#         type='ParallelSARDecoder',
#         enc_bi_rnn=False,
#         dec_bi_rnn=False,
#         dec_do_rnn=0,
#         dec_gru=False,
#         pred_dropout=0.1,
#         d_k=512,
#         pred_concat=True,
#         postprocessor=dict(type='AttentionPostprocessor'),
#         module_loss=dict(
#             type='CEModuleLoss', ignore_first_char=True, reduction='mean'),
#         dictionary=dict(
#             type='Dictionary',
#             dict_file=
#             '/content/mmocr/configs/textrecog/sar/../../../dicts/english_digits_symbols.txt',
#             with_start=True,
#             with_end=True,
#             same_start_end=True,
#             with_padding=True,
#             with_unknown=True),
#         max_seq_len=30))
# train_pipeline = [
#     dict(type='LoadImageFromFile', ignore_empty=True, min_size=2),
#     dict(type='LoadOCRAnnotations', with_text=True),
#     dict(
#         type='RescaleToHeight',
#         height=48,
#         min_width=48,
#         max_width=160,
#         width_divisor=4),
#     dict(type='PadToWidth', width=160),
#     dict(
#         type='PackTextRecogInputs',
#         meta_keys=('img_path', 'ori_shape', 'img_shape', 'valid_ratio'))
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='RescaleToHeight',
#         height=48,
#         min_width=48,
#         max_width=160,
#         width_divisor=4),
#     dict(type='PadToWidth', width=160),
#     dict(type='LoadOCRAnnotations', with_text=True),
#     dict(
#         type='PackTextRecogInputs',
#         meta_keys=('img_path', 'ori_shape', 'img_shape', 'valid_ratio'))
# ]
# tta_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 0,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }, {
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 1,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }, {
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 3,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }],
#                     [{
#                         'type': 'RescaleToHeight',
#                         'height': 48,
#                         'min_width': 48,
#                         'max_width': 160,
#                         'width_divisor': 4
#                     }], [{
#                         'type': 'PadToWidth',
#                         'width': 160
#                     }], [{
#                         'type': 'LoadOCRAnnotations',
#                         'with_text': True
#                     }],
#                     [{
#                         'type':
#                         'PackTextRecogInputs',
#                         'meta_keys':
#                         ('img_path', 'ori_shape', 'img_shape', 'valid_ratio')
#                     }]])
# ]
# train_list = [
#     dict(
#         type='OCRDataset',
#         data_root='tests/data/rec_toy_dataset/',
#         data_prefix=dict(img_path='imgs/'),
#         ann_file='labels.json',
#         pipeline=None,
#         test_mode=False)
# ]
# test_list = [
#     dict(
#         type='OCRDataset',
#         data_root='tests/data/rec_toy_dataset/',
#         data_prefix=dict(img_path='imgs/'),
#         ann_file='labels.json',
#         pipeline=None,
#         test_mode=True)
# ]
# train_dataloader = dict(
#     batch_size=5,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=False)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile', ignore_empty=True, min_size=2),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=True)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=True)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# work_dir = 'work_dirs/sar_resnet31_parallel-decoder_5e_toy/'

# %% [markdown]
# ### Train the SAR Text Recognizer
# Let's train the SAR text recognizer on the toy dataset for 10 epochs.

# %%
from mmengine.runner import Runner
import time

# Optionally, give visualizer a unique name to avoid dupliate instance being
# created in multiple runs
cfg.visualizer.name = f'{time.localtime()}'

runner = Runner.from_cfg(cfg)
runner.train()
# Out:
# 06/19 18:55:37 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/19 18:55:39 - mmengine - INFO - Config:
# toy_data_root = 'tests/data/rec_toy_dataset/'
# toy_rec_train = dict(
#     type='OCRDataset',
#     data_root='tests/data/rec_toy_dataset/',
#     data_prefix=dict(img_path='imgs/'),
#     ann_file='labels.json',
#     pipeline=None,
#     test_mode=False)
# toy_rec_test = dict(
#     type='OCRDataset',
#     data_root='tests/data/rec_toy_dataset/',
#     data_prefix=dict(img_path='imgs/'),
#     ann_file='labels.json',
#     pipeline=None,
#     test_mode=True)
# default_scope = 'mmocr'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# randomness = dict(seed=0)
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=10),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffer=dict(type='SyncBuffersHook'),
#     visualization=dict(
#         type='VisualizationHook',
#         interval=1,
#         enable=False,
#         show=False,
#         draw_gt=False,
#         draw_pred=False))
# log_level = 'INFO'
# log_processor = dict(type='LogProcessor', window_size=10, by_epoch=True)
# load_from = None
# resume = False
# val_evaluator = dict(
#     type='MultiDatasetsEvaluator',
#     metrics=[
#         dict(
#             type='WordMetric',
#             mode=['exact', 'ignore_case', 'ignore_case_symbol']),
#         dict(type='CharMetric')
#     ],
#     dataset_prefixes=['Toy'])
# test_evaluator = dict(
#     type='MultiDatasetsEvaluator',
#     metrics=[
#         dict(
#             type='WordMetric',
#             mode=['exact', 'ignore_case', 'ignore_case_symbol']),
#         dict(type='CharMetric')
#     ],
#     dataset_prefixes=['Toy'])
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='TextRecogLocalVisualizer',
#     name=
#     'time.struct_time(tm_year=2023, tm_mon=6, tm_mday=19, tm_hour=18, tm_min=55, tm_sec=36, tm_wday=0, tm_yday=170, tm_isdst=0)',
#     vis_backends=[dict(type='LocalVisBackend')])
# tta_model = dict(type='EncoderDecoderRecognizerTTAModel')
# optim_wrapper = dict(
#     type='OptimWrapper', optimizer=dict(type='Adam', lr=0.001))
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=100, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = None
# dictionary = dict(
#     type='Dictionary',
#     dict_file=
#     '/content/mmocr/configs/textrecog/sar/../../../dicts/english_digits_symbols.txt',
#     with_start=True,
#     with_end=True,
#     same_start_end=True,
#     with_padding=True,
#     with_unknown=True)
# model = dict(
#     type='SARNet',
#     data_preprocessor=dict(
#         type='TextRecogDataPreprocessor',
#         mean=[127, 127, 127],
#         std=[127, 127, 127]),
#     backbone=dict(type='ResNet31OCR'),
#     encoder=dict(
#         type='SAREncoder', enc_bi_rnn=False, enc_do_rnn=0.1, enc_gru=False),
#     decoder=dict(
#         type='ParallelSARDecoder',
#         enc_bi_rnn=False,
#         dec_bi_rnn=False,
#         dec_do_rnn=0,
#         dec_gru=False,
#         pred_dropout=0.1,
#         d_k=512,
#         pred_concat=True,
#         postprocessor=dict(type='AttentionPostprocessor'),
#         module_loss=dict(
#             type='CEModuleLoss', ignore_first_char=True, reduction='mean'),
#         dictionary=dict(
#             type='Dictionary',
#             dict_file=
#             '/content/mmocr/configs/textrecog/sar/../../../dicts/english_digits_symbols.txt',
#             with_start=True,
#             with_end=True,
#             same_start_end=True,
#             with_padding=True,
#             with_unknown=True),
#         max_seq_len=30))
# train_pipeline = [
#     dict(type='LoadImageFromFile', ignore_empty=True, min_size=2),
#     dict(type='LoadOCRAnnotations', with_text=True),
#     dict(
#         type='RescaleToHeight',
#         height=48,
#         min_width=48,
#         max_width=160,
#         width_divisor=4),
#     dict(type='PadToWidth', width=160),
#     dict(
#         type='PackTextRecogInputs',
#         meta_keys=('img_path', 'ori_shape', 'img_shape', 'valid_ratio'))
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='RescaleToHeight',
#         height=48,
#         min_width=48,
#         max_width=160,
#         width_divisor=4),
#     dict(type='PadToWidth', width=160),
#     dict(type='LoadOCRAnnotations', with_text=True),
#     dict(
#         type='PackTextRecogInputs',
#         meta_keys=('img_path', 'ori_shape', 'img_shape', 'valid_ratio'))
# ]
# tta_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 0,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }, {
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 1,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }, {
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 3,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }],
#                     [{
#                         'type': 'RescaleToHeight',
#                         'height': 48,
#                         'min_width': 48,
#                         'max_width': 160,
#                         'width_divisor': 4
#                     }], [{
#                         'type': 'PadToWidth',
#                         'width': 160
#                     }], [{
#                         'type': 'LoadOCRAnnotations',
#                         'with_text': True
#                     }],
#                     [{
#                         'type':
#                         'PackTextRecogInputs',
#                         'meta_keys':
#                         ('img_path', 'ori_shape', 'img_shape', 'valid_ratio')
#                     }]])
# ]
# train_list = [
#     dict(
#         type='OCRDataset',
#         data_root='tests/data/rec_toy_dataset/',
#         data_prefix=dict(img_path='imgs/'),
#         ann_file='labels.json',
#         pipeline=None,
#         test_mode=False)
# ]
# test_list = [
#     dict(
#         type='OCRDataset',
#         data_root='tests/data/rec_toy_dataset/',
#         data_prefix=dict(img_path='imgs/'),
#         ann_file='labels.json',
#         pipeline=None,
#         test_mode=True)
# ]
# train_dataloader = dict(
#     batch_size=5,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=False)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile', ignore_empty=True, min_size=2),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=True)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=True)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# work_dir = 'work_dirs/sar_resnet31_parallel-decoder_5e_toy/'
#
# 06/19 18:55:41 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/19 18:55:41 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 06/19 18:55:48 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/19 18:55:48 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/19 18:55:48 - mmengine - INFO - Checkpoints will be saved to /content/mmocr/work_dirs/sar_resnet31_parallel-decoder_5e_toy.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 06/19 18:55:49 - mmengine - INFO - Epoch(train)   [1][1/2]  lr: 1.0000e-03  eta: 0:06:08  time: 1.8513  data_time: 0.1682  memory: 1441  loss: 4.5186  loss_ce: 4.5186
# 06/19 18:55:50 - mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:55:50 - mmengine - INFO - Epoch(train)   [1][2/2]  lr: 1.0000e-03  eta: 0:03:22  time: 1.0236  data_time: 0.0896  memory: 1442  loss: 4.8185  loss_ce: 4.8185
# 06/19 18:55:50 - mmengine - INFO - Epoch(val)   [1][ 1/10]    eta: 0:00:02  time: 0.2898  data_time: 0.1728  memory: 909
# 06/19 18:55:50 - mmengine - INFO - Epoch(val)   [1][ 2/10]    eta: 0:00:01  time: 0.1962  data_time: 0.0892  memory: 909
# 06/19 18:55:50 - mmengine - INFO - Epoch(val)   [1][ 3/10]    eta: 0:00:01  time: 0.1649  data_time: 0.0617  memory: 909
# 06/19 18:55:50 - mmengine - INFO - Epoch(val)   [1][ 4/10]    eta: 0:00:00  time: 0.1495  data_time: 0.0482  memory: 909
# 06/19 18:55:50 - mmengine - INFO - Epoch(val)   [1][ 5/10]    eta: 0:00:00  time: 0.1393  data_time: 0.0389  memory: 909
# 06/19 18:55:50 - mmengine - INFO - Epoch(val)   [1][ 6/10]    eta: 0:00:00  time: 0.1324  data_time: 0.0327  memory: 909
# 06/19 18:55:51 - mmengine - INFO - Epoch(val)   [1][ 7/10]    eta: 0:00:00  time: 0.1275  data_time: 0.0283  memory: 909
# 06/19 18:55:51 - mmengine - INFO - Epoch(val)   [1][ 8/10]    eta: 0:00:00  time: 0.1240  data_time: 0.0252  memory: 909
# 06/19 18:55:51 - mmengine - INFO - Epoch(val)   [1][ 9/10]    eta: 0:00:00  time: 0.1212  data_time: 0.0225  memory: 909
# 06/19 18:55:51 - mmengine - INFO - Epoch(val)   [1][10/10]    eta: 0:00:00  time: 0.1193  data_time: 0.0206  memory: 909
# 06/19 18:55:51 - mmengine - INFO - Epoch(val) [1][10/10]    Toy/recog/word_acc: 0.0000  Toy/recog/word_acc_ignore_case: 0.0000  Toy/recog/word_acc_ignore_case_symbol: 0.0000  Toy/recog/char_recall: 0.1613  Toy/recog/char_precision: 0.5000  data_time: 0.0206  time: 0.1193
# 06/19 18:55:51 - mmengine - INFO - Epoch(train)   [2][1/2]  lr: 1.0000e-03  eta: 0:02:24  time: 0.7330  data_time: 0.0675  memory: 1443  loss: 4.5772  loss_ce: 4.5772
# 06/19 18:55:51 - mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:55:51 - mmengine - INFO - Epoch(train)   [2][2/2]  lr: 1.0000e-03  eta: 0:01:54  time: 0.5834  data_time: 0.0522  memory: 1443  loss: 4.4002  loss_ce: 4.4002
# 06/19 18:55:51 - mmengine - INFO - Epoch(val)   [2][ 1/10]    eta: 0:00:00  time: 0.1008  data_time: 0.0040  memory: 909
# 06/19 18:55:51 - mmengine - INFO - Epoch(val)   [2][ 2/10]    eta: 0:00:00  time: 0.1007  data_time: 0.0039  memory: 909
# 06/19 18:55:51 - mmengine - INFO - Epoch(val)   [2][ 3/10]    eta: 0:00:00  time: 0.1004  data_time: 0.0035  memory: 909
# 06/19 18:55:52 - mmengine - INFO - Epoch(val)   [2][ 4/10]    eta: 0:00:00  time: 0.1002  data_time: 0.0032  memory: 909
# 06/19 18:55:52 - mmengine - INFO - Epoch(val)   [2][ 5/10]    eta: 0:00:00  time: 0.1002  data_time: 0.0033  memory: 909
# 06/19 18:55:52 - mmengine - INFO - Epoch(val)   [2][ 6/10]    eta: 0:00:00  time: 0.1003  data_time: 0.0033  memory: 909
# 06/19 18:55:52 - mmengine - INFO - Epoch(val)   [2][ 7/10]    eta: 0:00:00  time: 0.1005  data_time: 0.0034  memory: 909
# 06/19 18:55:52 - mmengine - INFO - Epoch(val)   [2
- mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:56:15 - mmengine - INFO - Epoch(train)  [15][2/2]  lr: 1.0000e-03  eta: 0:00:34  time: 0.1413  data_time: 0.0100  memory: 1443  loss: 1.3867  loss_ce: 1.3867
# 06/19 18:56:15 - mmengine - INFO - Epoch(val)  [15][ 1/10]    eta: 0:00:01  time: 0.1040  data_time: 0.0069  memory: 909
# 06/19 18:56:15 - mmengine - INFO - Epoch(val)  [15][ 2/10]    eta: 0:00:00  time: 0.1045  data_time: 0.0074  memory: 909
# 06/19 18:56:15 - mmengine - INFO - Epoch(val)  [15][ 3/10]    eta: 0:00:00  time: 0.1048  data_time: 0.0077  memory: 909
# 06/19 18:56:15 - mmengine - INFO - Epoch(val)  [15][ 4/10]    eta: 0:00:00  time: 0.1047  data_time: 0.0074  memory: 909
# 06/19 18:56:15 - mmengine - INFO - Epoch(val)  [15][ 5/10]    eta: 0:00:00  time: 0.1049  data_time: 0.0076  memory: 909
# 06/19 18:56:16 - mmengine - INFO - Epoch(val)  [15][ 6/10]    eta: 0:00:00  time: 0.1046  data_time: 0.0072  memory: 909
# 06/19 18:56:16 - mmengine - INFO - Epoch(val)  [15][ 7/10]    eta: 0:00:00  time: 0.1045  data_time: 0.0072  memory: 909
# 06/19 18:56:16 - mmengine - INFO - Epoch(val)  [15][ 8/10]    eta: 0:00:00  time: 0.1043  data_time: 0.0072  memory: 909
# 06/19 18:56:16 - mmengine - INFO - Epoch(val)  [15][ 9/10]    eta: 0:00:00  time: 0.1040  data_time: 0.0068  memory: 909
# 06/19 18:56:16 - mmengine - INFO - Epoch(val)  [15][10/10]    eta: 0:00:00  time: 0.1038  data_time: 0.0064  memory: 909
# 06/19 18:56:16 - mmengine - INFO - Epoch(val) [15][10/10]    Toy/recog/word_acc: 0.1000  Toy/recog/word_acc_ignore_case: 0.1000  Toy/recog/word_acc_ignore_case_symbol: 0.1000  Toy/recog/char_recall: 0.3065  Toy/recog/char_precision: 0.2794  data_time: 0.0065  time: 0.1038
# 06/19 18:56:16 - mmengine - INFO - Epoch(train)  [16][1/2]  lr: 1.0000e-03  eta: 0:00:33  time: 0.1416  data_time: 0.0104  memory: 1443  loss: 1.3801  loss_ce: 1.3801
# 06/19 18:56:16 - mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:56:16 - mmengine - INFO - Epoch(train)  [16][2/2]  lr: 1.0000e-03  eta: 0:00:33  time: 0.1410  data_time: 0.0102  memory: 1443  loss: 1.2975  loss_ce: 1.2975
# 06/19 18:56:16 - mmengine - INFO - Epoch(val)  [16][ 1/10]    eta: 0:00:01  time: 0.1038  data_time: 0.0063  memory: 909
# 06/19 18:56:17 - mmengine - INFO - Epoch(val)  [16][ 2/10]    eta: 0:00:00  time: 0.1032  data_time: 0.0057  memory: 909
# 06/19 18:56:17 - mmengine - INFO - Epoch(val)  [16][ 3/10]    eta: 0:00:00  time: 0.1031  data_time: 0.0055  memory: 909
# 06/19 18:56:17 - mmengine - INFO - Epoch(val)  [16][ 4/10]    eta: 0:00:00  time: 0.1029  data_time: 0.0055  memory: 909
# 06/19 18:56:17 - mmengine - INFO - Epoch(val)  [16][ 5/10]    eta: 0:00:00  time: 0.1030  data_time: 0.0054  memory: 909
# 06/19 18:56:17 - mmengine - INFO - Epoch(val)  [16][ 6/10]    eta: 0:00:00  time: 0.1031  data_time: 0.0054  memory: 909
# ...
# 06/19 18:59:06 - mmengine - INFO - Epoch(train)  [97][1/2]  lr: 1.0000e-03  eta: 0:00:01  time: 0.1414  data_time: 0.0102  memory: 1443  loss: 0.3941  loss_ce: 0.3941
# 06/19 18:59:06 - mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:59:06 - mmengine - INFO - Epoch(train)  [97][2/2]  lr: 1.0000e-03  eta: 0:00:00  time: 0.1420  data_time: 0.0109  memory: 1443  loss: 0.3760  loss_ce: 0.3760
# 06/19 18:59:06 - mmengine - INFO - Epoch(val)  [97][ 1/10]    eta: 0:00:00  time: 0.1023  data_time: 0.0040  memory: 909
# 06/19 18:59:06 - mmengine - INFO - Epoch(val)  [97][ 2/10]    eta: 0:00:00  time: 0.1018  data_time: 0.0035  memory: 909
# 06/19 18:59:06 - mmengine - INFO - Epoch(val)  [97][ 3/10]    eta: 0:00:00  time: 0.1019  data_time: 0.0036  memory: 909
# 06/19 18:59:06 - mmengine - INFO - Epoch(val)  [97][ 4/10]    eta: 0:00:00  time: 0.1018  data_time: 0.0036  memory: 909
# 06/19 18:59:06 - mmengine - INFO - Epoch(val)  [97][ 5/10]    eta: 0:00:00  time: 0.1019  data_time: 0.0038  memory: 909
# 06/19 18:59:06 - mmengine - INFO - Epoch(val)  [97][ 6/10]    eta: 0:00:00  time: 0.1018  data_time: 0.0038  memory: 909
# 06/19 18:59:07 - mmengine - INFO - Epoch(val)  [97][ 7/10]    eta: 0:00:00  time: 0.1018  data_time: 0.0038  memory: 909
# 06/19 18:59:07 - mmengine - INFO - Epoch(val)  [97][ 8/10]    eta: 0:00:00  time: 0.1018  data_time: 0.0038  memory: 909
# 06/19 18:59:07 - mmengine - INFO - Epoch(val)  [97][ 9/10]    eta: 0:00:00  time: 0.1019  data_time: 0.0038  memory: 909
# 06/19 18:59:07 - mmengine - INFO - Epoch(val)  [97][10/10]    eta: 0:00:00  time: 0.1019  data_time: 0.0040  memory: 909
# 06/19 18:59:07 - mmengine - INFO - Epoch(val) [97][10/10]    Toy/recog/word_acc: 0.5000  Toy/recog/word_acc_ignore_case: 0.5000  Toy/recog/word_acc_ignore_case_symbol: 0.5000  Toy/recog/char_recall: 0.6452  Toy/recog/char_precision: 0.6452  data_time: 0.0038  time: 0.1021
# 06/19 18:59:07 - mmengine - INFO - Epoch(train)  [98][1/2]  lr: 1.0000e-03  eta: 0:00:00  time: 0.1419  data_time: 0.0109  memory: 1443  loss: 0.4013  loss_ce: 0.4013
# 06/19 18:59:07 - mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:59:07 - mmengine - INFO - Epoch(train)  [98][2/2]  lr: 1.0000e-03  eta: 0:00:00  time: 0.1413  data_time: 0.0100  memory: 1443  loss: 0.3789  loss_ce: 0.3789
# 06/19 18:59:07 - mmengine - INFO - Epoch(val)  [98][ 1/10]    eta: 0:00:00  time: 0.1020  data_time: 0.0040  memory: 909
# 06/19 18:59:07 - mmengine - INFO - Epoch(val)  [98][ 2/10]    eta: 0:00:00  time: 0.1020  data_time: 0.0040  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][ 3/10]    eta: 0:00:00  time: 0.1021  data_time: 0.0039  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][ 4/10]    eta: 0:00:00  time: 0.1025  data_time: 0.0044  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][ 5/10]    eta: 0:00:00  time: 0.1024  data_time: 0.0042  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][ 6/10]    eta: 0:00:00  time: 0.1024  data_time: 0.0041  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][ 7/10]    eta: 0:00:00  time: 0.1025  data_time: 0.0040  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][ 8/10]    eta: 0:00:00  time: 0.1026  data_time: 0.0043  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][ 9/10]    eta: 0:00:00  time: 0.1025  data_time: 0.0043  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val)  [98][10/10]    eta: 0:00:00  time: 0.1023  data_time: 0.0042  memory: 909
# 06/19 18:59:08 - mmengine - INFO - Epoch(val) [98][10/10]    Toy/recog/word_acc: 0.6000  Toy/recog/word_acc_ignore_case: 0.6000  Toy/recog/word_acc_ignore_case_symbol: 0.6000  Toy/recog/char_recall: 0.6935  Toy/recog/char_precision: 0.6719  data_time: 0.0042  time: 0.1024
# 06/19 18:59:08 - mmengine - INFO - Epoch(train)  [99][1/2]  lr: 1.0000e-03  eta: 0:00:00  time: 0.1408  data_time: 0.0094  memory: 1443  loss: 0.3751  loss_ce: 0.3751
# 06/19 18:59:09 - mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:59:09 - mmengine - INFO - Epoch(train)  [99][2/2]  lr: 1.0000e-03  eta: 0:00:00  time: 0.1409  data_time: 0.0095  memory: 1443  loss: 0.3851  loss_ce: 0.3851
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 1/10]    eta: 0:00:00  time: 0.1022  data_time: 0.0041  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 2/10]    eta: 0:00:00  time: 0.1028  data_time: 0.0049  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 3/10]    eta: 0:00:00  time: 0.1027  data_time: 0.0049  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 4/10]    eta: 0:00:00  time: 0.1023  data_time: 0.0044  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 5/10]    eta: 0:00:00  time: 0.1023  data_time: 0.0044  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 6/10]    eta: 0:00:00  time: 0.1025  data_time: 0.0046  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 7/10]    eta: 0:00:00  time: 0.1025  data_time: 0.0046  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 8/10]    eta: 0:00:00  time: 0.1023  data_time: 0.0043  memory: 909
# 06/19 18:59:09 - mmengine - INFO - Epoch(val)  [99][ 9/10]    eta: 0:00:00  time: 0.1023  data_time: 0.0042  memory: 909
# 06/19 18:59:10 - mmengine - INFO - Epoch(val)  [99][10/10]    eta: 0:00:00  time: 0.1023  data_time: 0.0042  memory: 909
# 06/19 18:59:10 - mmengine - INFO - Epoch(val) [99][10/10]    Toy/recog/word_acc: 0.6000  Toy/recog/word_acc_ignore_case: 0.6000  Toy/recog/word_acc_ignore_case_symbol: 0.6000  Toy/recog/char_recall: 0.6935  Toy/recog/char_precision: 0.6719  data_time: 0.0041  time: 0.1023
# 06/19 18:59:10 - mmengine - INFO - Epoch(train) [100][1/2]  lr: 1.0000e-03  eta: 0:00:00  time: 0.1408  data_time: 0.0091  memory: 1443  loss: 0.3850  loss_ce: 0.3850
# 06/19 18:59:10 - mmengine - INFO - Exp name: sar_resnet31_parallel-decoder_5e_toy_20230619_185536
# 06/19 18:59:10 - mmengine - INFO - Epoch(train) [100][2/2]  lr: 1.0000e-03  eta: 0:00:00  time: 0.1407  data_time: 0.0086  memory: 1443  loss: 0.3836  loss_ce: 0.3836
# 06/19 18:59:10 - mmengine - INFO - Saving checkpoint at 100 epochs
# 06/19 18:59:15 - mmengine - INFO - Epoch(val) [100][ 1/10]    eta: 0:00:01  time: 0.1078  data_time: 0.0043  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 2/10]    eta: 0:00:01  time: 0.1103  data_time: 0.0043  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 3/10]    eta: 0:00:00  time: 0.1117  data_time: 0.0049  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 4/10]    eta: 0:00:00  time: 0.1120  data_time: 0.0054  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 5/10]    eta: 0:00:00  time: 0.1125  data_time: 0.0061  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 6/10]    eta: 0:00:00  time: 0.1125  data_time: 0.0062  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 7/10]    eta: 0:00:00  time: 0.1127  data_time: 0.0065  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 8/10]    eta: 0:00:00  time: 0.1134  data_time: 0.0073  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][ 9/10]    eta: 0:00:00  time: 0.1134  data_time: 0.0075  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][10/10]    eta: 0:00:00  time: 0.1134  data_time: 0.0077  memory: 909
# 06/19 18:59:16 - mmengine - INFO - Epoch(val) [100][10/10]    Toy/recog/word_acc: 0.7000  Toy/recog/word_acc_ignore_case: 0.7000  Toy/recog/word_acc_ignore_case_symbol: 0.7000  Toy/recog/char_recall: 0.6774  Toy/recog/char_precision: 0.7500  data_time: 0.0073  time: 0.1124
# SARNet(
#   (data_preprocessor): TextRecogDataPreprocessor()
#   (backbone): ResNet31OCR(
#     (conv1_1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1_1): ReLU(inplace=True)
#     (conv1_2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1_2): ReLU(inplace=True)
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (block2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (block3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (conv3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU(inplace=True)
#     (pool4): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=True)
#     (block4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (conv4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU(inplace=True)
#     (block5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (conv5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu5): ReLU(inplace=True)
#   )
#   init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Uniform', 'layer': 'BatchNorm2d'}]
#   (encoder): SAREncoder(
#     (rnn_encoder): LSTM(512, 512, num_layers=2, batch_first=True)
#     (linear): Linear(in_features=512, out_features=512, bias=True)
#   )
#   init_cfg=[{'type': 'Xavier', 'layer': 'Conv2d'}, {'type': 'Uniform', 'layer': 'BatchNorm2d'}]
#   (decoder): ParallelSARDecoder(
#     (module_loss): CEModuleLoss(
#       (loss_ce): CrossEntropyLoss()
#     )
#     (conv1x1_1): Linear(in_features=512, out_features=512, bias=True)
#     (conv3x3_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv1x1_2): Linear(in_features=512, out_features=1, bias=True)
#     (rnn_decoder): LSTM(512, 512, num_layers=2, batch_first=True)
#     (embedding): Embedding(93, 512, padding_idx=91)
#     (pred_dropout): Dropout(p=0.1, inplace=False)
#     (prediction): Linear(in_features=1536, out_features=93, bias=True)
#     (softmax): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# ### Perform inference and Visualize the Predictions
#
# We can test the model through [Infernecer](https://mmocr.readthedocs.io/en/dev-1.x/user_guides/inference.html), then print out and visualize its return values. Inferencer can also accepts many more types of inputs, just feel free to play around with it.

# %%
import matplotlib.pyplot as plt
from mmocr.apis import TextRecInferencer

img = '/content/Unknown-7.png'
checkpoint = "work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth"
cfg_file = "configs/textrecog/sar/sar_resnet31_parallel-decoder_5e_toy.py"

infer = TextRecInferencer(cfg_file, checkpoint)
result = infer(img, return_vis=True)

print(f'result: {result["predictions"]}' )

plt.figure(figsize=(9, 16))
plt.imshow(result['visualization'][0])
plt.show()
# Out:
# Loads checkpoint by local backend from path: work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-01c65442357e> in <cell line: 8>()
#       6 cfg_file = "configs/textrecog/sar/sar_resnet31_parallel-decoder_5e_toy.py"
#       7
# ----> 8 infer = TextRecInferencer(cfg_file, checkpoint)
#       9 result = infer(img, return_vis=True)
#      10
#
# /content/mmocr/mmocr/apis/inferencers/base_mmocr_inferencer.py in __init__(self, model, weights, device, scope)
#      63         self.num_unnamed_imgs = 0
#      64         init_default_scope(scope)
# ---> 65         super().__init__(
#      66             model=model, weights=weights, device=device, scope=scope)
#      67         self.model = revert_sync_batchnorm(self.model)
#
# /usr/local/lib/python3.10/dist-packages/mmengine/infer/infer.py in __init__(self, model, weights, device, scope, show_progress)
#     178             device = get_device()
#     179
# --> 180         self.model = self._init_model(cfg, weights, device)  # type: ignore
#     181         self.pipeline = self._init_pipeline(cfg)
#     182         self.collate_fn = self._init_collate(cfg)
#
# /usr/local/lib/python3.10/dist-packages/mmengine/infer/infer.py in _init_model(self, cfg, weights, device)
#     451         checkpoint: Optional[dict] = None
#     452         if weights is not None:
# --> 453             checkpoint = _load_checkpoint(weights, map_location='cpu')
#     454
#     455         if not cfg:
#
# /usr/local/lib/python3.10/dist-packages/mmengine/runner/checkpoint.py in _load_checkpoint(filename, map_location, logger)
#     546         information, which depends on the checkpoint.
#     547     """
# --> 548     return CheckpointLoader.load_checkpoint(filename, map_location, logger)
#     549
#     550
#
# /usr/local/lib/python3.10/dist-packages/mmengine/runner/checkpoint.py in load_checkpoint(cls, filename, map_location, logger)
#     328             f'{filename}',
#     329             logger=logger)
# --> 330         return checkpoint_loader(filename, map_location)
#     331
#     332
#
# /usr/local/lib/python3.10/dist-packages/mmengine/runner/checkpoint.py in load_from_local(filename, map_location)
#     344     filename = osp.expanduser(filename)
#     345     if not osp.isfile(filename):
# --> 346         raise FileNotFoundError(f'{filename} can not be found.')
#     347     checkpoint = torch.load(filename, map_location=map_location)
#     348     return checkpoint
#
# FileNotFoundError: work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth can not be found.

# %% [markdown]
# ## Evaluating SAR
#
# This section provides guidance on how to evaluate a model using with pretrained weights in a Python interpreter. Apart from such a practice, another common practice is to test a model from CLI (command line interface), as illustrated [here](https://mmocr.readthedocs.io/en/dev-1.x/get_started/quick_run.html#testing).
#
# Typically, the evaluation process involves several steps:
#
# 1. Convert the dataset into [formats supported by MMOCR](https://mmocr.readthedocs.io/en/dev-1.x/basic_concepts/datasets.html). It should not be a concern if the dataset is obtained from [Dataset Preparer](https://mmocr.readthedocs.io/en/dev-1.x/user_guides/data_prepare/dataset_preparer.html), which can download, extract and convert the dataset into a MMOCR-ready form with a single line of command. Otherwise, you will need to manually download and prepare the dataset following the [guide](https://mmocr.readthedocs.io/en/dev-1.x/user_guides/data_prepare/det.html), or even have to write a custom conversion script if your dataset is not on the list.
# 2. Modify the config for testing.
# 3. Test the model.
#
# Now we will demonstrate how to test a model on different datasets.

# %% [markdown]
# ### Toy Dataset
#
# With the checkpoint we obtained from the last section, we can evaluate it on the toy dataset again. Some more explanataions about the evaulation metrics are available [here](https://mmocr.readthedocs.io/en/dev-1.x/basic_concepts/evaluation.html).

# %%
from mmengine.runner import Runner
import time

# The location of pretrained weight
cfg['load_from'] = 'work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth'

# Optionally, give visualizer a unique name to avoid dupliate instance being
# created in multiple runs
cfg.visualizer.name = f'{time.localtime()}'

runner = Runner.from_cfg(cfg)
runner.test()
# Out:
# 06/19 19:00:19 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/19 19:00:21 - mmengine - INFO - Config:
# toy_data_root = 'tests/data/rec_toy_dataset/'
# toy_rec_train = dict(
#     type='OCRDataset',
#     data_root='tests/data/rec_toy_dataset/',
#     data_prefix=dict(img_path='imgs/'),
#     ann_file='labels.json',
#     pipeline=None,
#     test_mode=False)
# toy_rec_test = dict(
#     type='OCRDataset',
#     data_root='tests/data/rec_toy_dataset/',
#     data_prefix=dict(img_path='imgs/'),
#     ann_file='labels.json',
#     pipeline=None,
#     test_mode=True)
# default_scope = 'mmocr'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# randomness = dict(seed=0)
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=10),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffer=dict(type='SyncBuffersHook'),
#     visualization=dict(
#         type='VisualizationHook',
#         interval=1,
#         enable=False,
#         show=False,
#         draw_gt=False,
#         draw_pred=False))
# log_level = 'INFO'
# log_processor = dict(type='LogProcessor', window_size=10, by_epoch=True)
# load_from = 'work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth'
# resume = False
# val_evaluator = dict(
#     type='MultiDatasetsEvaluator',
#     metrics=[
#         dict(
#             type='WordMetric',
#             mode=['exact', 'ignore_case', 'ignore_case_symbol']),
#         dict(type='CharMetric')
#     ],
#     dataset_prefixes=['Toy'])
# test_evaluator = dict(
#     type='MultiDatasetsEvaluator',
#     metrics=[
#         dict(
#             type='WordMetric',
#             mode=['exact', 'ignore_case', 'ignore_case_symbol']),
#         dict(type='CharMetric')
#     ],
#     dataset_prefixes=['Toy'])
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='TextRecogLocalVisualizer',
#     name=
#     'time.struct_time(tm_year=2023, tm_mon=6, tm_mday=19, tm_hour=19, tm_min=0, tm_sec=19, tm_wday=0, tm_yday=170, tm_isdst=0)',
#     vis_backends=[dict(type='LocalVisBackend')])
# tta_model = dict(type='EncoderDecoderRecognizerTTAModel')
# optim_wrapper = dict(
#     type='OptimWrapper', optimizer=dict(type='Adam', lr=0.001))
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=100, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = None
# dictionary = dict(
#     type='Dictionary',
#     dict_file=
#     '/content/mmocr/configs/textrecog/sar/../../../dicts/english_digits_symbols.txt',
#     with_start=True,
#     with_end=True,
#     same_start_end=True,
#     with_padding=True,
#     with_unknown=True)
# model = dict(
#     type='SARNet',
#     data_preprocessor=dict(
#         type='TextRecogDataPreprocessor',
#         mean=[127, 127, 127],
#         std=[127, 127, 127]),
#     backbone=dict(type='ResNet31OCR'),
#     encoder=dict(
#         type='SAREncoder', enc_bi_rnn=False, enc_do_rnn=0.1, enc_gru=False),
#     decoder=dict(
#         type='ParallelSARDecoder',
#         enc_bi_rnn=False,
#         dec_bi_rnn=False,
#         dec_do_rnn=0,
#         dec_gru=False,
#         pred_dropout=0.1,
#         d_k=512,
#         pred_concat=True,
#         postprocessor=dict(type='AttentionPostprocessor'),
#         module_loss=dict(
#             type='CEModuleLoss', ignore_first_char=True, reduction='mean'),
#         dictionary=dict(
#             type='Dictionary',
#             dict_file=
#             '/content/mmocr/configs/textrecog/sar/../../../dicts/english_digits_symbols.txt',
#             with_start=True,
#             with_end=True,
#             same_start_end=True,
#             with_padding=True,
#             with_unknown=True),
#         max_seq_len=30))
# train_pipeline = [
#     dict(type='LoadImageFromFile', ignore_empty=True, min_size=2),
#     dict(type='LoadOCRAnnotations', with_text=True),
#     dict(
#         type='RescaleToHeight',
#         height=48,
#         min_width=48,
#         max_width=160,
#         width_divisor=4),
#     dict(type='PadToWidth', width=160),
#     dict(
#         type='PackTextRecogInputs',
#         meta_keys=('img_path', 'ori_shape', 'img_shape', 'valid_ratio'))
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='RescaleToHeight',
#         height=48,
#         min_width=48,
#         max_width=160,
#         width_divisor=4),
#     dict(type='PadToWidth', width=160),
#     dict(type='LoadOCRAnnotations', with_text=True),
#     dict(
#         type='PackTextRecogInputs',
#         meta_keys=('img_path', 'ori_shape', 'img_shape', 'valid_ratio'))
# ]
# tta_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 0,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }, {
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 1,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }, {
#             'type':
#             'ConditionApply',
#             'true_transforms': [{
#                 'type':
#                 'ImgAugWrapper',
#                 'args': [{
#                     'cls': 'Rot90',
#                     'k': 3,
#                     'keep_size': False
#                 }]
#             }],
#             'condition':
#             "results['img_shape'][1]<results['img_shape'][0]"
#         }],
#                     [{
#                         'type': 'RescaleToHeight',
#                         'height': 48,
#                         'min_width': 48,
#                         'max_width': 160,
#                         'width_divisor': 4
#                     }], [{
#                         'type': 'PadToWidth',
#                         'width': 160
#                     }], [{
#                         'type': 'LoadOCRAnnotations',
#                         'with_text': True
#                     }],
#                     [{
#                         'type':
#                         'PackTextRecogInputs',
#                         'meta_keys':
#                         ('img_path', 'ori_shape', 'img_shape', 'valid_ratio')
#                     }]])
# ]
# train_list = [
#     dict(
#         type='OCRDataset',
#         data_root='tests/data/rec_toy_dataset/',
#         data_prefix=dict(img_path='imgs/'),
#         ann_file='labels.json',
#         pipeline=None,
#         test_mode=False)
# ]
# test_list = [
#     dict(
#         type='OCRDataset',
#         data_root='tests/data/rec_toy_dataset/',
#         data_prefix=dict(img_path='imgs/'),
#         ann_file='labels.json',
#         pipeline=None,
#         test_mode=True)
# ]
# train_dataloader = dict(
#     batch_size=5,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=False)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile', ignore_empty=True, min_size=2),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=True)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ConcatDataset',
#         datasets=[
#             dict(
#                 type='OCRDataset',
#                 data_root='tests/data/rec_toy_dataset/',
#                 data_prefix=dict(img_path='imgs/'),
#                 ann_file='labels.json',
#                 pipeline=None,
#                 test_mode=True)
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='RescaleToHeight',
#                 height=48,
#                 min_width=48,
#                 max_width=160,
#                 width_divisor=4),
#             dict(type='PadToWidth', width=160),
#             dict(type='LoadOCRAnnotations', with_text=True),
#             dict(
#                 type='PackTextRecogInputs',
#                 meta_keys=('img_path', 'ori_shape', 'img_shape',
#                            'valid_ratio'))
#         ]))
# work_dir = 'work_dirs/sar_resnet31_parallel-decoder_5e_toy/'
#
# 06/19 19:00:25 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/19 19:00:25 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Loads checkpoint by local backend from path: work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth
# 06/19 19:01:10 - mmengine - INFO - Load checkpoint from work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 1/10]    eta: 0:00:03  time: 0.3629  data_time: 0.2034  memory: 1136
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 2/10]    eta: 0:00:01  time: 0.2403  data_time: 0.1054  memory: 811
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 3/10]    eta: 0:00:01  time: 0.1965  data_time: 0.0713  memory: 811
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 4/10]    eta: 0:00:01  time: 0.1729  data_time: 0.0548  memory: 811
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 5/10]    eta: 0:00:00  time: 0.1584  data_time: 0.0442  memory: 811
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 6/10]    eta: 0:00:00  time: 0.1486  data_time: 0.0371  memory: 811
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 7/10]    eta: 0:00:00  time: 0.1417  data_time: 0.0320  memory: 811
# 06/19 19:01:11 - mmengine - INFO - Epoch(test) [ 8/10]    eta: 0:00:00  time: 0.1366  data_time: 0.0285  memory: 811
# 06/19 19:01:12 - mmengine - INFO - Epoch(test) [ 9/10]    eta: 0:00:00  time: 0.1330  data_time: 0.0262  memory: 811
# 06/19 19:01:12 - mmengine - INFO - Epoch(test) [10/10]    eta: 0:00:00  time: 0.1299  data_time: 0.0239  memory: 811
# 06/19 19:01:12 - mmengine - INFO - Epoch(test) [10/10]    Toy/recog/word_acc: 0.7000  Toy/recog/word_acc_ignore_case: 0.7000  Toy/recog/word_acc_ignore_case_symbol: 0.7000  Toy/recog/char_recall: 0.6774  Toy/recog/char_precision: 0.7500  data_time: 0.0239  time: 0.1299
# OrderedDict([('Toy/recog/word_acc', 0.7),
#              ('Toy/recog/word_acc_ignore_case', 0.7),
#              ('Toy/recog/word_acc_ignore_case_symbol', 0.7),
#              ('Toy/recog/char_recall', 0.6774),
#              ('Toy/recog/char_precision', 0.75)])

# %% [markdown]
# It's also possible to evaluate with a stronger and more generalized pretrained weight, which were trained on larger datasets and achieved quite competitve acadmical performance, though it may not defeat the previous checkpoint overfitted to the toy dataset. ([readme](https://mmocr.readthedocs.io/en/dev-1.x/textrecog_models.html#sar))

# %%
# The location of pretrained weight
cfg['load_from'] = 'https://download.openmmlab.com/mmocr/textrecog/sar/sar_resnet31_parallel-decoder_5e_st-sub_mj-sub_sa_real/sar_resnet31_parallel-decoder_5e_st-sub_mj-sub_sa_real_20220915_171910-04eb4e75.pth'
cfg.visualizer.name = f'{time.localtime()}'
runner = Runner.from_cfg(cfg)
runner.test()

# %% [markdown]
# ### SVTP Dataset
#
# SVTP dataset is one of the six commonly used academic test sets that systematically reflects a text recognizer's performance. Now we will evaluate SAR on this dataset, and we are going to use [Dataset Preparer](https://mmocr.readthedocs.io/en/dev-1.x/user_guides/data_prepare/dataset_preparer.html) to get it prepared first.

# %%
# !python tools/dataset_converters/prepare_dataset.py svtp --task textrecog

# %% [markdown]
# SVTP is now available in `data/svtp`, and the dataset config is available at `configs/textrecog/_base_/datasets/svtp.py`. Now we first point the `test_dataloader` to SVTP, then perform testing with the overfitted checkpoint. As this checkpoint is just overfitted to such a small dataset, it's not surprising that it performs well on the toy dataset and bad on SVTP.

# %%
from mmengine import Config

svtp_cfg = Config.fromfile('configs/textrecog/_base_/datasets/svtp.py')
svtp_cfg.svtp_textrecog_test.pipeline = cfg.test_pipeline
cfg.test_dataloader.dataset = svtp_cfg.svtp_textrecog_test

# The location of pretrained weight
cfg['load_from'] = 'work_dirs/sar_resnet31_parallel-decoder_5e_toy/epoch_100.pth'

# Optionally, give visualizer a unique name to avoid dupliate instance being
# created in multiple runs
cfg.visualizer.name = f'{time.localtime()}'

runner = Runner.from_cfg(cfg)
runner.test()

# %% [markdown]
# Let's evaluate the pretrained one for comparision.

# %%
# The location of pretrained weight
cfg['load_from'] = 'https://download.openmmlab.com/mmocr/textrecog/sar/sar_resnet31_parallel-decoder_5e_st-sub_mj-sub_sa_real/sar_resnet31_parallel-decoder_5e_st-sub_mj-sub_sa_real_20220915_171910-04eb4e75.pth'
cfg.visualizer.name = f'{time.localtime()}'
runner = Runner.from_cfg(cfg)
runner.test()
